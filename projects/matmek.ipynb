# %%
import decay_v3

a = -1
theta = 0.8
I = 0.1
dt = 0.8
Nt = 10
decay_v3.plot_numerical_and_exact(theta, I, a, Nt*dt, dt)

# %% [markdown]
# theta = 0.0
# decay_v3.plot_numerical_and_exact(theta, I, a, Nt*dt, dt)

# %%
theta = 1.0
decay_v3.plot_numerical_and_exact(theta, I, a, Nt*dt, dt)

# %%
theta = 0.5
decay_v3.plot_numerical_and_exact(theta, I, a, Nt*dt, dt)

# %%
theta = 0.25
decay_v3.plot_numerical_and_exact(theta, I, a, Nt*dt, dt)

# %%
decay_v3.interact_plot_numerical_and_exact(I, a, dt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ipywidgets import interact, FloatSlider
# ----> 3 decay_v3.interact_plot_numerical_and_exact(I, a, dt)
#
# File c:\Users\cbf\course-projects-matmek\projects\decay_v3.py:55, in interact_plot_numerical_and_exact(I, a, dt)
#      50 def interact_plot_numerical_and_exact(I: float = 0.1, a: float = 0.8, dt: float = 0.8):
#      51     """Interactively compare the numerical and exact solution in a plot."""
#      52     interact(
#      53         plot_numerical_and_exact,
#      54         theta=FloatSlider(min=0, max=1, step=0.1, value=0.5),
# ---> 55         I=fixed(I),
#      56         a=fixed(a),
#      57         T=FloatSlider(min=0, max=10, step=1, value=5)
#      58     )
#
# NameError: name 'fixed' is not defined
